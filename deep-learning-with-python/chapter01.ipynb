# %% [markdown]
# ![ai](./pics/ai.png)

# %% [markdown]
# ![form](./pics/form.png)

# %% [markdown]
# ![parameterize](./pics/parameterize.png)

# %% [markdown]
# ![loss](./pics/loss.png)

# %% [markdown]
# ![optimizer](./pics/optimizer.png)
